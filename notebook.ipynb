# %% [markdown]
# ## Application Package reproducibility
#
# ### Personas
#
# * **Alice** developed a Water Body detection Earth Observation application and package it as an EO Application Package
# * **Bob** scripts the execution of application
#
# ### Scenario
#
# Alice included in the water bodies detection Application Package software repository a Continuous Integration configuration relying on Github Actions to:
#
# * build the containers
# * push the built containers to Github container registry
# * update the Application Package with these new container references
# * push the updated Application Package to Github's artifact registry

# %% [markdown]
# Alice sent an email to Bob:

# %% [markdown]
# <hr>
# from: alice@acme.io
#
# to: bob@acme.io
#
# subject: Detecting water bodies with NDWI and the Otsu threshold
#
#
# Hi Bob!
#
# checkout my new application package for detecting water bodies using NDWI and the Ostu threshold.
#
# I've ran it over our test site bounding box and preliminary result look promising.
#
# The github repo is https://github.com/eoap/quickwin and I've just released version 1.0.0.
#
# Let me know!
#
# Cheers
#
# Alice
# <hr>

# %% [markdown]
# With this information, Bob scripts the Application Execution in a Jupyter Notebook.
#
# His environment has a container engine (e.g. podman or docker) and the cwltool CWL runner.

# %% [markdown]
# ## Running the Scenario

# %%
import argparse
import asyncio
import json
import os
from datetime import datetime
from io import StringIO

import nest_asyncio
import pystac
import rasterio
from cwltool.main import main
from ipyleaflet import GeoJSON, Map
from pydantic_yaml import to_yaml_str
from pystac_client import Client
from rasterio.features import dataset_features, sieve

from helpers import Params, get_param_model_fields, get_release_assets, stage_in

from shutil import which

nest_asyncio.apply()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 17
#      14 from pystac_client import Client
#      15 from rasterio.features import dataset_features, sieve
# ---> 17 from helpers import Params, get_param_model_fields, get_release_assets, stage_in
#      19 from shutil import which
#      21 nest_asyncio.apply()
#
# File ~/Documents/repos/eoap/open-reproducible-app-package/helpers.py:6
#       4 from typing import Any, Dict, Optional, List
#       5 from pydantic import BaseModel, DirectoryPath
# ----> 6 from pydantic.fields import ModelField, FieldInfo
#       7 import json
#       8 import requests
#
# ImportError: cannot import name 'ModelField' from 'pydantic.fields' (/Users/simonevaccari/Documents/repos/eoap/open-reproducible-app-package/env_reproducible_app/lib/python3.12/site-packages/pydantic/fields.py)

# %% [markdown]
# ## Check the container engine

# %%
if which("podman"):
    podman = True
elif which("docker"):
    podman = False
else:
    raise ValueError("No container engine")

# %% [markdown]
# ## Application Package releases
#
# Bob uses Github API to list the artifacts published by Alice in the release

# %%
assets = get_release_assets(
    user="eoap",
    repo="quickwin",
    token=os.environ["GH_PAT"],
)

assets
# Out:
# {'1.0.0': [{'url': 'https://github.com/Terradue/app-package-training-bids23/releases/download/1.0.0/app-water-bodies-cloud-native.1.0.0.cwl',
#    'cwl': <cwl_utils.parser.cwl_v1_0.Workflow at 0x7f839fd75a90>,
#    'label': 'Water bodies detection based on NDWI and otsu threshold',
#    'doc': 'Water bodies detection based on NDWI and otsu threshold applied to Sentinel-2 COG STAC items'},
#   {'url': 'https://github.com/Terradue/app-package-training-bids23/releases/download/1.0.0/app-water-body-cloud-native.1.0.0.cwl',
#    'cwl': <cwl_utils.parser.cwl_v1_0.Workflow at 0x7f839fd023d0>,
#    'label': 'Water bodies detection based on NDWI and the otsu threshold',
#    'doc': 'Water bodies detection based on NDWI and otsu threshold applied to a single Sentinel-2 COG STAC item'},
#   {'url': 'https://github.com/Terradue/app-package-training-bids23/releases/download/1.0.0/app-water-body.1.0.0.cwl',
#    'cwl': <cwl_utils.parser.cwl_v1_0.Workflow at 0x7f83a1b501f0>,
#    'label': 'Water body detection based on NDWI and the otsu threshold',
#    'doc': 'Water bodies detection based on NDWI and otsu threshold applied to Sentinel-2 or Landsat-9 staged acquisitions'}]}

# %% [markdown]
# ## Running the Application Package to detect water bodies on Sentinel-2 data
#
# Alice published three Application Packages.
#
#  Bob selects the one processing several Sentinel-2 acquisitions provided as STAC Items

# %%
app_package = assets["1.0.0"][0]

print(app_package["doc"])

print(app_package["url"])
# Out:
# Water bodies detection based on NDWI and otsu threshold applied to Sentinel-2 COG STAC items
# https://github.com/Terradue/app-package-training-bids23/releases/download/1.0.0/app-water-bodies-cloud-native.1.0.0.cwl

# %% [markdown]
# The Application Package parameters are discovered and a pydantic model is created

# %%
Params.set_fields(**get_param_model_fields(cwl_obj=app_package["cwl"]))

Params.get_fields()
# Out:
# {'aoi': ModelField(name='aoi', type=str, required=True),
#  'bands': ModelField(name='bands', type=List[str], required=False, default=['green', 'nir']),
#  'epsg': ModelField(name='epsg', type=str, required=False, default='EPSG:4326'),
#  'stac_items': ModelField(name='stac_items', type=List[str], required=True)}

# %% [markdown]
# The Application Package takes as inputs:
# - one or more STAC Items
# - a list of the bands for the normalized difference
# - an area of interest
# - the EPSG code used for the area of interest coordinates
#
#  Bob uses a STAC API endpoint to discover Sentinel-2 acquisitions over an area of interest and time of interest

# %%
URL = "https://earth-search.aws.element84.com/v1/"

headers = []

cat = Client.open(URL, headers=headers)
cat
# Out:
# <Client id=earth-search-aws>

# %% [markdown]
# Bod defines the search parameter and get the results:

# %%
# Collection
collections = ["sentinel-2-l2a"]

# Start and end dates
start_date = datetime.fromisoformat("2021-07-08T00:00:00")
stop_date = datetime.fromisoformat("2021-07-08T23:59:59")

bbox = [-121.399, 39.834, -120.74, 40.472]

# Other metadata
cloud_cover = 5

# Query by AOI, start and end date and other params
query = cat.search(
    collections=collections,
    datetime=(start_date, stop_date),
    bbox=bbox,
    query={"eo:cloud_cover": {"lt": cloud_cover}},
)

# %% [markdown]
# Bob plots the Sentinel-2 discovered STAC Items footprint:

# %%
center = ((bbox[1] + bbox[3]) / 2, (bbox[0] + bbox[2]) / 2)

m = Map(center=center, zoom=8)

for item in list(query.item_collection()):
    geo_json = GeoJSON(
        name=item.id,
        data=item.geometry,
        style={
            "opacity": 1,
            "dashArray": "9",
            "fillOpacity": 0.1,
            "weight": 1,
            "color": "blue",
        },
        hover_style={"color": "white", "dashArray": "0", "fillOpacity": 0.5},
    )
    m.add_layer(geo_json)

m
# Out:
# Map(center=[40.153000000000006, -121.0695], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_i…

# %% [markdown]
# Bob lists the STAC Items self link, these are the URLs to the Sentinel-2 STAC Items to process:

# %%
[item.get_self_href() for item in list(query.item_collection())]
# Out:
# ['https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2A_10TFK_20210708_0_L2A',
#  'https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2A_10TFK_20210708_1_L2A']

# %% [markdown]
# And creates the parameters for running the Application Package (the epsg and bands input parameters have default values)

# %%
params = Params(
    aoi=",".join([str(elem) for elem in bbox]),
    stac_items=[item.self_href for item in query.item_collection()],
    epsg="EPSG:4326",
    bands=["green", "nir"],
)

params.dict()
# Out:
# {'aoi': '-121.399,39.834,-120.74,40.472',
#  'bands': ['green', 'nir'],
#  'epsg': 'EPSG:4326',
#  'stac_items': ['https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2A_10TFK_20210708_0_L2A',
#   'https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2A_10TFK_20210708_1_L2A']}

# %% [markdown]
# Bob writes a YAML file with the parameters and their values:

# %%
with open("params-s2.yaml", "w") as file:
    print(to_yaml_str(params), file=file)

# %% [markdown]
# The file `params.yaml` contains:
#
# ```yaml
# aoi: -121.399,39.834,-120.74,40.472
# bands:
# - green
# - nir
# epsg: EPSG:4326
# stac_items:
# - https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2A_10TFK_20210708_0_L2A
# - https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2A_10TFK_20210708_1_L2A
# ```

# %% [markdown]
# Bob uses the CWL runner `cwltool` Python API to script the Application Package execution

# %%
parsed_args = argparse.Namespace(
    podman=podman,
    parallel=True,
    debug=False,
    outdir="./runs",
    workflow=app_package["url"],
    job_order=["params-s2.yaml"],
)

stream_out = StringIO()
stream_err = StringIO()

res = main(
    args=parsed_args,
    stdout=stream_out,
)

assert res == 0
# Out:
# INFO /data/work/open-reproducible-app-package/env_reproducible_app/lib/python3.9/site-packages/ipykernel_launcher.py 3.1.20231020140205
# INFO [workflow ] starting step node_water_bodies
# INFO [workflow ] start
# INFO [step node_water_bodies] start
# INFO [workflow node_water_bodies] start
# INFO [workflow node_water_bodies] starting step node_crop
# INFO [step node_crop] start
# INFO [step node_crop] start
# INFO [step node_water_bodies] start
# INFO [workflow node_water_bodies_2] starting step node_crop_2
# INFO [workflow node_water_bodies_2] start
# INFO [step node_crop_2] start
# INFO [step node_crop_2] start
# WARNING [job node_crop] Skipping Docker software container '--memory' limit despite presence of ResourceRequirement with ramMin and/or ramMax setting. Consider running with --strict-memory-limit for increased portability assurance.
# WARNING [job node_crop] Skipping Docker software container '--cpus' limit despite presence of ResourceRequirement with coresMin and/or coresMax setting. Consider running with --strict-cpu-limit for increased portability assurance.
# INFO [job node_crop] /tmp/h0vl2wbo$ docker \
#     run \
#     -i \
#     --mount=type=bind,source=/tmp/h0vl2wbo,target=/EqECVR \
#     --mount=type=bind,source=/tmp/6gt147fu,target=/tmp \
#     --workdir=/EqECVR \
#     --read-only=true \
#     --user=1000:1000 \
#     --rm \
#     --cidfile=/tmp/g2e089lm/20231109085606-963229.cid \
#     --env=TMPDIR=/tmp \
#     --env=HOME=/EqECVR \
#     --env=PATH=/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin \
#     --env=PYTHONPATH=/app \
#     ghcr.io/terradue/app-package-training-bids23/crop@sha256:c4ef31e7eef8acb6be8565636396f8e4548585a6609b4a2d10e38ad4c3004ff4 \
#     python \
#     -m \
#     app \
#     --aoi \
#     -121.399,39.834,-120.74,40.472 \
#     --band \
#     green \
#     --epsg \
#     EPSG:4326 \
#     --input-item \
#     https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2A_10TFK_20210708_0_L2A
# WARNING [job node_crop_2] Skipping Docker software container '--memory' limit despite presence of ResourceRequirement with ramMin and/or ramMax setting. Consider running with --strict-memory-limit for increased portability assurance.
# WARNING [job node_crop_2] Skipping Docker software container '--cpus' limit despite presence of ResourceRequirement with coresMin and/or coresMax setting. Consider running with --strict-cpu-limit for increased portability assurance.
# INFO [job node_crop_2] /tmp/x0jy_qzp$ docker \
#     run \
#     -i \
#     --mount=type=bind,source=/tmp/x0jy_qzp,target=/EqECVR \
#     --mount=type=bind,source=/tmp/2l51rpij,target=/tmp \
#     --workdir=/EqECVR \
#     --read-only=true \
#     --user=1000:1000 \
#     --rm \
#     --cidfile=/tmp/8xpevz0r/20231109085606-974964.cid \
#     --env=TMPDIR=/tmp \
#     --env=HOME=/EqECVR \
#     --env=PATH=/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin \
#     --env=PYTHONPATH=/app \
#     ghcr.io/terradue/app-package-training-bids23/crop@sha256:c4ef31e7eef8acb6be8565636396f8e4548585a6609b4a2d10e38ad4c3004ff4 \
#     python \
#     -m \
#     app \
#     --aoi \
#     -121.399,39.834,-120.74,40.472 \
#     --band \
#     nir \
#     --epsg \
#     EPSG:4326 \
#     --input-item \
#     https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2A_10TFK_20210708_0_L2A
# WARNING [job node_crop_3] Skipping Docker software container '--memory' limit despite presence of ResourceRequirement with ramMin and/or ramMax setting. Consider running with --strict-memory-limit for increased portability assurance.
# WARNING [job node_crop_3] Skipping Docker software container '--cpus' limit despite presence of ResourceRequirement with coresMin and/or coresMax setting. Consider running with --strict-cpu-limit for increased portability assurance.
# INFO [job node_crop_3] /tmp/ya93vr56$ docker \
#     run \
#     -i \
#     --mount=type=bind,source=/tmp/ya93vr56,target=/EqECVR \
#     --mount=type=bind,source=/tmp/0lx8xk93,target=/tmp \
#     --workdir=/EqECVR \
#     --read-only=true \
#     --user=1000:1000 \
#     --rm \
#     --cidfile=/tmp/13jqrvdf/20231109085607-006913.cid \
#     --env=TMPDIR=/tmp \
#     --env=HOME=/EqECVR \
#     --env=PATH=/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin \
#     --env=PYTHONPATH=/app \
#     ghcr.io/terradue/app-package-training-bids23/crop@sha256:c4ef31e7eef8acb6be8565636396f8e4548585a6609b4a2d10e38ad4c3004ff4 \
#     python \
#     -m \
#     app \
#     --aoi \
#     -121.399,39.834,-120.74,40.472 \
#     --band \
#     green \
#     --epsg \
#     EPSG:4326 \
#     --input-item \
#     https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2A_10TFK_20210708_1_L2A
# WARNING [job node_crop_4] Skipping Docker software container '--memory' limit despite presence of ResourceRequirement with ramMin and/or ramMax setting. Consider running with --strict-memory-limit for increased portability assurance.
# WARNING [job node_crop_4] Skipping Docker software container '--cpus' limit despite presence of ResourceRequirement with coresMin and/or coresMax setting. Consider running with --strict-cpu-limit for increased portability assurance.
# INFO [job node_crop_4] /tmp/m_8409by$ docker \
#     run \
#     -i \
#     --mount=type=bind,source=/tmp/m_8409by,target=/EqECVR \
#     --mount=type=bind,source=/tmp/2iw5wgb8,target=/tmp \
#     --workdir=/EqECVR \
#     --read-only=true \
#     --user=1000:1000 \
#     --rm \
#     --cidfile=/tmp/uunytv58/20231109085607-013230.cid \
#     --env=TMPDIR=/tmp \
#     --env=HOME=/EqECVR \
#     --env=PATH=/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin \
#     --env=PYTHONPATH=/app \
#     ghcr.io/terradue/app-package-training-bids23/crop@sha256:c4ef31e7eef8acb6be8565636396f8e4548585a6609b4a2d10e38ad4c3004ff4 \
#     python \
#     -m \
#     app \
#     --aoi \
#     -121.399,39.834,-120.74,40.472 \
#     --band \
#     nir \
#     --epsg \
#     EPSG:4326 \
#     --input-item \
#     https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2A_10TFK_20210708_1_L2A
# INFO [job node_crop_2] Max memory used: 370MiB
# INFO [job node_crop] Max memory used: 377MiB
# INFO [job node_crop] completed success
# INFO [job node_crop_2] completed success
# INFO [step node_crop] completed success
# INFO [workflow node_water_bodies] starting step node_normalized_difference
# INFO [step node_normalized_difference] start
# WARNING [job node_normalized_difference] Skipping Docker software container '--memory' limit despite presence of ResourceRequirement with ramMin and/or ramMax setting. Consider running with --strict-memory-limit for increased portability assurance.
# WARNING [job node_normalized_difference] Skipping Docker software container '--cpus' limit despite presence of ResourceRequirement with coresMin and/or coresMax setting. Consider running with --strict-cpu-limit for increased portability assurance.
# INFO [job node_normalized_difference] /tmp/pmtmq7pj$ docker \
#     run \
#     -i \
#     --mount=type=bind,source=/tmp/pmtmq7pj,target=/EqECVR \
#     --mount=type=bind,source=/tmp/yp0s6lib,target=/tmp \
#     --mount=type=bind,source=/tmp/h0vl2wbo/crop_green.tif,target=/var/lib/cwl/stg931251cb-1cd7-449e-89a1-da5765391a4d/crop_green.tif,readonly \
#     --mount=type=bind,source=/tmp/x0jy_qzp/crop_nir.tif,target=/var/lib/cwl/stgae72f928-5065-4107-bd3a-23a5ddea34ff/crop_nir.tif,readonly \
#     --workdir=/EqECVR \
#     --read-only=true \
#     --user=1000:1000 \
#     --rm \
#     --cidfile=/tmp/z6df5m1f/20231109085700-056209.cid \
#     --env=TMPDIR=/tmp \
#     --env=HOME=/EqECVR \
#     --env=PATH=/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin \
#     --env=PYTHONPATH=/app \
#     ghcr.io/terradue/app-package-training-bids23/norm_diff@sha256:ff26cb57b3cfa1085f5e263b62ae2586ed12370b1447e11bebdebcdc195f1cfb \
#     python \
#     -m \
#     app \
#     /var/lib/cwl/stg931251cb-1cd7-449e-89a1-da5765391a4d/crop_green.tif \
#     /var/lib/cwl/stgae72f928-5065-4107-bd3a-23a5ddea34ff/crop_nir.tif
# INFO [job node_normalized_difference] Max memory used: 594MiB
# INFO [job node_normalized_difference] completed success
# INFO [step node_normalized_difference] completed success
# INFO [workflow node_water_bodies] starting step node_otsu
# INFO [step node_otsu] start
# WARNING [job node_otsu] Skipping Docker software container '--memory' limit despite presence of ResourceRequirement with ramMin and/or ramMax setting. Consider running with --strict-memory-limit for increased portability assurance.
# WARNING [job node_otsu] Skipping Docker software container '--cpus' limit despite presence of ResourceRequirement with coresMin and/or coresMax setting. Consider running with --strict-cpu-limit for increased portability assurance.
# INFO [job node_otsu] /tmp/0oj2e9n_$ docker \
#     run \
#     -i \
#     --mount=type=bind,source=/tmp/0oj2e9n_,target=/EqECVR \
#     --mount=type=bind,source=/tmp/03k16vh0,target=/tmp \
#     --mount=type=bind,source=/tmp/pmtmq7pj/norm_diff.tif,target=/var/lib/cwl/stg0d09a10d-3357-4f49-9375-31dff776edd4/norm_diff.tif,readonly \
#     --workdir=/EqECVR \
#     --read-only=true \
#     --user=1000:1000 \
#     --rm \
#     --cidfile=/tmp/8jvwzzpe/20231109085707-404364.cid \
#     --env=TMPDIR=/tmp \
#     --env=HOME=/EqECVR \
#     --env=PATH=/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin \
#     --env=PYTHONPATH=/app \
#     ghcr.io/terradue/app-package-training-bids23/otsu@sha256:72b5579eae5cb993b32102705f9075cabfba940edabd1c921b7e025e9fb6c31e \
#     python \
#     -m \
#     app \
#     /var/lib/cwl/stg0d09a10d-3357-4f49-9375-31dff776edd4/norm_diff.tif
# INFO [job node_otsu] Max memory used: 326MiB
# INFO [job node_otsu] completed success
# INFO [step node_otsu] completed success
# INFO [workflow node_water_bodies] completed success
# INFO [job node_crop_4] Max memory used: 383MiB
# INFO [job node_crop_4] completed success
# INFO [job node_crop_3] Max memory used: 377MiB
# INFO [job node_crop_3] completed success
# INFO [step node_crop_2] completed success
# INFO [workflow node_water_bodies_2] starting step node_normalized_difference_2
# INFO [step node_normalized_difference_2] start
# WARNING [job node_normalized_difference_2] Skipping Docker software container '--memory' limit despite presence of ResourceRequirement with ramMin and/or ramMax setting. Consider running with --strict-memory-limit for increased portability assurance.
# WARNING [job node_normalized_difference_2] Skipping Docker software container '--cpus' limit despite presence of ResourceRequirement with coresMin and/or coresMax setting. Consider running with --strict-cpu-limit for increased portability assurance.
# INFO [job node_normalized_difference_2] /tmp/d180qrbz$ docker \
#     run \
#     -i \
#     --mount=type=bind,source=/tmp/d180qrbz,target=/EqECVR \
#     --mount=type=bind,source=/tmp/xfy9lihz,target=/tmp \
#     --mount=type=bind,source=/tmp/ya93vr56/crop_green.tif,target=/var/lib/cwl/stgec3986f5-72b2-4b6f-9bce-0f404005317f/crop_green.tif,readonly \
#     --mount=type=bind,source=/tmp/m_8409by/crop_nir.tif,target=/var/lib/cwl/stg100fb3d1-f66d-41ad-9d84-89220adc63ce/crop_nir.tif,readonly \
#     --workdir=/EqECVR \
#     --read-only=true \
#     --user=1000:1000 \
#     --rm \
#     --cidfile=/tmp/oxu7geey/20231109085802-373086.cid \
#     --env=TMPDIR=/tmp \
#     --env=HOME=/EqECVR \
#     --env=PATH=/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin \
#     --env=PYTHONPATH=/app \
#     ghcr.io/terradue/app-package-training-bids23/norm_diff@sha256:ff26cb57b3cfa1085f5e263b62ae2586ed12370b1447e11bebdebcdc195f1cfb \
#     python \
#     -m \
#     app \
#     /var/lib/cwl/stgec3986f5-72b2-4b6f-9bce-0f404005317f/crop_green.tif \
#     /var/lib/cwl/stg100fb3d1-f66d-41ad-9d84-89220adc63ce/crop_nir.tif
# INFO [job node_normalized_difference_2] Max memory used: 594MiB
# INFO [job node_normalized_difference_2] completed success
# INFO [step node_normalized_difference_2] completed success
# INFO [workflow node_water_bodies_2] starting step node_otsu_2
# INFO [step node_otsu_2] start
# WARNING [job node_otsu_2] Skipping Docker software container '--memory' limit despite presence of ResourceRequirement with ramMin and/or ramMax setting. Consider running with --strict-memory-limit for increased portability assurance.
# WARNING [job node_otsu_2] Skipping Docker software container '--cpus' limit despite presence of ResourceRequirement with coresMin and/or coresMax setting. Consider running with --strict-cpu-limit for increased portability assurance.
# INFO [job node_otsu_2] /tmp/ntx5jf_c$ docker \
#     run \
#     -i \
#     --mount=type=bind,source=/tmp/ntx5jf_c,target=/EqECVR \
#     --mount=type=bind,source=/tmp/e0xjecvq,target=/tmp \
#     --mount=type=bind,source=/tmp/d180qrbz/norm_diff.tif,target=/var/lib/cwl/stg2f748878-c01b-4cef-94f3-c1f77ce98c5c/norm_diff.tif,readonly \
#     --workdir=/EqECVR \
#     --read-only=true \
#     --user=1000:1000 \
#     --rm \
#     --cidfile=/tmp/ea9b5aex/20231109085809-340818.cid \
#     --env=TMPDIR=/tmp \
#     --env=HOME=/EqECVR \
#     --env=PATH=/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin \
#     --env=PYTHONPATH=/app \
#     ghcr.io/terradue/app-package-training-bids23/otsu@sha256:72b5579eae5cb993b32102705f9075cabfba940edabd1c921b7e025e9fb6c31e \
#     python \
#     -m \
#     app \
#     /var/lib/cwl/stg2f748878-c01b-4cef-94f3-c1f77ce98c5c/norm_diff.tif
# INFO [job node_otsu_2] Max memory used: 492MiB
# INFO [job node_otsu_2] completed success
# INFO [step node_otsu_2] completed success
# INFO [workflow node_water_bodies_2] completed success
# INFO [step node_water_bodies] completed success
# INFO [workflow ] starting step node_stac
# INFO [step node_stac] start
# WARNING [job node_stac] Skipping Docker software container '--memory' limit despite presence of ResourceRequirement with ramMin and/or ramMax setting. Consider running with --strict-memory-limit for increased portability assurance.
# WARNING [job node_stac] Skipping Docker software container '--cpus' limit despite presence of ResourceRequirement with coresMin and/or coresMax setting. Consider running with --strict-cpu-limit for increased portability assurance.
# INFO [job node_stac] /tmp/i6jddzuk$ docker \
#     run \
#     -i \
#     --mount=type=bind,source=/tmp/i6jddzuk,target=/EqECVR \
#     --mount=type=bind,source=/tmp/utwvpo3e,target=/tmp \
#     --mount=type=bind,source=/tmp/0oj2e9n_/otsu.tif,target=/var/lib/cwl/stg36233271-07fb-44d3-abf8-211d0546c425/otsu.tif,readonly \
#     --mount=type=bind,source=/tmp/ntx5jf_c/otsu.tif,target=/var/lib/cwl/stg9cb27243-e8e8-41d7-8e70-07b5d24bae1f/otsu.tif,readonly \
#     --workdir=/EqECVR \
#     --read-only=true \
#     --user=1000:1000 \
#     --rm \
#     --cidfile=/tmp/u7gbbkw7/20231109085812-474326.cid \
#     --env=TMPDIR=/tmp \
#     --env=HOME=/EqECVR \
#     --env=PATH=/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin \
#     --env=PYTHONPATH=/app \
#     ghcr.io/terradue/app-package-training-bids23/stac@sha256:0b23e5cbd67aa2030a88da6d987bf5863e33bbd6f2492d3d12bc9b7f5bafc3cc \
#     python \
#     -m \
#     app \
#     --input-item \
#     https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2A_10TFK_20210708_0_L2A \
#     --water-body \
#     /var/lib/cwl/stg36233271-07fb-44d3-abf8-211d0546c425/otsu.tif \
#     --input-item \
#     https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2A_10TFK_20210708_1_L2A \
#     --water-body \
#     /var/lib/cwl/stg9cb27243-e8e8-41d7-8e70-07b5d24bae1f/otsu.tif
# INFO [job node_stac] Max memory used: 38MiB
# INFO [job node_stac] completed success
# INFO [step node_stac] completed success
# INFO [workflow ] completed success
# INFO Final process status is success

# %% [markdown]
# This execution generates as output a JSON file listing all files produced.
#
# The JSON contains the output defined in the CWL workflow that can be accessed with:
#
# ```python
# os.path.basename(app_package["cwl"].outputs[0].id)
# ```

# %%
results = json.loads(stream_out.getvalue())

results[os.path.basename(app_package["cwl"].outputs[0].id)]
# Out:
# {'location': 'file:///data/work/open-reproducible-app-package/runs/i6jddzuk',
#  'basename': 'i6jddzuk',
#  'class': 'Directory',
#  'listing': [{'class': 'Directory',
#    'location': 'file:///data/work/open-reproducible-app-package/runs/i6jddzuk/S2A_10TFK_20210708_1_L2A',
#    'basename': 'S2A_10TFK_20210708_1_L2A',
#    'listing': [{'class': 'File',
#      'location': 'file:///data/work/open-reproducible-app-package/runs/i6jddzuk/S2A_10TFK_20210708_1_L2A/otsu.tif',
#      'basename': 'otsu.tif',
#      'checksum': 'sha1$eac01b59127e027758b6b4add8c4b7cb6475ba42',
#      'size': 286925,
#      'path': '/data/work/open-reproducible-app-package/runs/i6jddzuk/S2A_10TFK_20210708_1_L2A/otsu.tif'},
#     {'class': 'File',
#      'location': 'file:///data/work/open-reproducible-app-package/runs/i6jddzuk/S2A_10TFK_20210708_1_L2A/S2A_10TFK_20210708_1_L2A.json',
#      'basename': 'S2A_10TFK_20210708_1_L2A.json',
#      'checksum': 'sha1$34642536318a6ca807ab038cc55685082d22825c',
#      'size': 4889,
#      'path': '/data/work/open-reproducible-app-package/runs/i6jddzuk/S2A_10TFK_20210708_1_L2A/S2A_10TFK_20210708_1_L2A.json'}],
#    'path': '/data/work/open-reproducible-app-package/runs/i6jddzuk/S2A_10TFK_20210708_1_L2A'},
#   {'class': 'Directory',
#    'location': 'file:///data/work/open-reproducible-app-package/runs/i6jddzuk/S2A_10TFK_20210708_0_L2A',
#    'basename': 'S2A_10TFK_20210708_0_L2A',
#    'listing': [{'class': 'File',
#      'location': 'file:///data/work/open-reproducible-app-package/runs/i6jddzuk/S2A_10TFK_20210708_0_L2A/otsu.tif',
#      'basename': 'otsu.tif',
#      'checksum': 'sha1$210598cf619d49eabfdc24414bd445f59668f3bd',
#      'size': 289288,
#      'path': '/data/work/open-reproducible-app-package/runs/i6jddzuk/S2A_10TFK_20210708_0_L2A/otsu.tif'},
#     {'class': 'File',
#      'location': 'file:///data/work/open-reproducible-app-package/runs/i6jddzuk/S2A_10TFK_20210708_0_L2A/S2A_10TFK_20210708_0_L2A.json',
#      'basename': 'S2A_10TFK_20210708_0_L2A.json',
#      'checksum': 'sha1$d2ec2f86148cdf8d2fe6681a462d3c680f141d3c',
#      'size': 4889,
#      'path': '/data/work/open-reproducible-app-package/runs/i6jddzuk/S2A_10TFK_20210708_0_L2A/S2A_10TFK_20210708_0_L2A.json'}],
#    'path': '/data/work/open-reproducible-app-package/runs/i6jddzuk/S2A_10TFK_20210708_0_L2A'},
#   {'class': 'File',
#    'location': 'file:///data/work/open-reproducible-app-package/runs/i6jddzuk/catalog.json',
#    'basename': 'catalog.json',
#    'checksum': 'sha1$70a28aeddcbf6e8b18a81cd97761a18a4973daf9',
#    'size': 500,
#    'path': '/data/work/open-reproducible-app-package/runs/i6jddzuk/catalog.json'}],
#  'path': '/data/work/open-reproducible-app-package/runs/i6jddzuk'}

# %% [markdown]
# Bob writes a simple code to find the STAC Catalog path and then list the contents of that STAC Catalog:

# %%
cat = pystac.read_file(
    [
        listing["path"]
        for listing in results[os.path.basename(app_package["cwl"].outputs[0].id)][
            "listing"
        ]
        if "catalog.json" in listing["path"]
    ][0]
)

cat.describe()
# Out:
# * <Catalog id=catalog>
#   * <Item id=S2A_10TFK_20210708_0_L2A>
#   * <Item id=S2A_10TFK_20210708_1_L2A>

# %% [markdown]
# Bob uses the STAC Python library to open the first STAC Item produced:

# %%
item = next(cat.get_items())
item
# Out:
# <Item id=S2A_10TFK_20210708_0_L2A>

# %% [markdown]
# Bob gets the path of the ostu step asset:

# %%
asset_href = item.get_assets()["data"].get_absolute_href()

asset_href
# Out:
# '/data/work/open-reproducible-app-package/runs/i6jddzuk/S2A_10TFK_20210708_0_L2A/otsu.tif'

# %% [markdown]
# Bob applies the sieve algorithm and then vectorizes the water bodies.
#
# Finally the water bodies are added to a map

# %%
# Define the threshold size to remove small features (in pixels)
threshold = 100  # Adjust this threshold as needed
connectivity = 4  # Use 4-connected pixels for the sieve operation

center = ((bbox[1] + bbox[3]) / 2, (bbox[0] + bbox[2]) / 2)

m = Map(center=center, zoom=8)

with rasterio.open(asset_href) as src:
    result = sieve(src, threshold, connectivity=8)
    for geom in dataset_features(src, band=True, as_mask=True):
        geo_json = GeoJSON(
            name="",
            data=geom,
            style={
                "opacity": 1,
                "fillOpacity": 0.1,
                "weight": 1,
                "color": "red",
            },
            hover_style={"color": "red", "dashArray": "0", "fillOpacity": 0.5},
        )
        m.add_layer(geo_json)
m
# Out:
# Map(center=[40.153000000000006, -121.0695], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_i…

# %% [markdown]
# Bob sends an email to Alice
#
# <hr>
# from: bob@acme.io
#
# to: alice@acme.io
#
# subject: RE:Detecting water bodies with NDWI and the Otsu threshold
#
#
# Hi Alice!
#
# The results look promising!
#
# Cheers,
#
# Bob
# <hr>
